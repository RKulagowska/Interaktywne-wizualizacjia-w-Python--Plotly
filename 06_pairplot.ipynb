# %% [markdown]
# <a href="https://colab.research.google.com/github/RKulagowska/Interaktywne-wizualizacjia-w-Python--Plotly/blob/main/06_pairplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('iris')
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
sns.set()
sns.pairplot(data= df)

# %%
sns.pairplot(data= df, hue='species')

# %%
sns.pairplot(data= df, hue='species', palette='pastel')

# %%
g= sns.PairGrid(df)

# %%
g= sns.PairGrid(df)
g.map_diag(sns.kdeplot)

# %%
g= sns.PairGrid(df)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)

# %%
g= sns.PairGrid(df)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=6)

# %%
g= sns.PairGrid(df, hue='species')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=6)

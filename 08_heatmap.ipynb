# %% [markdown]
# <a href="https://colab.research.google.com/github/RKulagowska/Interaktywne-wizualizacjia-w-Python--Plotly/blob/main/08_heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
x= np.random.randn(100,100)
x
# Out:
# array([[-1.07961611,  0.32481536,  0.42636953, ...,  0.71749913,
#          0.52012118, -1.47438392],
#        [-1.45918543,  0.17706856, -1.01365524, ...,  0.97141589,
#         -1.39754105,  0.49801804],
#        [-1.9231803 , -1.18611339,  0.29956969, ...,  0.06228831,
#          0.25035119, -1.12072716],
#        ...,
#        [-0.21861024, -0.43031692, -0.67149401, ..., -1.06514147,
#          0.40704464, -0.91167903],
#        [ 1.55470199, -2.96824915, -0.14050077, ..., -0.68793639,
#         -1.44381868, -0.67973295],
#        [ 0.35226766,  0.48785414,  0.2847368 , ..., -1.17359318,
#         -0.2031383 ,  0.65459896]])

# %%
sns.heatmap(x)

# %%
df= sns.load_dataset('flights')
df.head(5)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
df.head(2)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118

# %%
df.pivot(index='month',columns='year', values='passengers')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
df= df.pivot(index='month',columns='year', values='passengers')

# %%
sns.heatmap(df)

# %%
sns.heatmap(df, annot=True, fmt= 'd')

# %%
sns.heatmap(df, annot=True, fmt= 'd', cmap= 'viridis')
